# %%
import pandas as pd

# %%
df = pd.read_csv('clean_data.csv')

# %%
df.head()
# Out:
#    Age  Transaction_Count_30d  Mobile_App_Logins  Social_Media_Score  \
# 0   56                     88                 18           75.759841
# 1   69                    142                 25           79.367816
# 2   46                     26                 29           38.747638
# 3   32                      5                 22            6.930618
# 4   60                     38                 23           39.798200
#
#    Monthly_Income    Total_Debt  Savings_Balance  Credit_Score  \
# 0      685.890070  45609.656078      2175.720442           385
# 1     1200.253941  37313.651220     15795.689669           794
# 2     1197.358489  42534.285531      2359.943407           539
# 3     1227.066948  42627.489789     11249.016576           373
# 4      980.643854   9631.844467      2721.247990           385
#
#    Debt_to_Income  Is_High_Risk  City_SAMARQAND  City_TOSHKENT  City_UNKNOWN  \
# 0        5.540746             1           False          False          True
# ...

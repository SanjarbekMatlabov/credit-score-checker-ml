# %%
import pandas as pd

# %%
data = pd.read_csv('raw_data.csv')

# %%
data.head()
# Out:
#   Client_ID Full_Name       City  Gender  Age    Education Marital_Status  \
# 0      ID_0    Name_0    UNKNOWN  Female   26          PhD         Single
# 1      ID_1    Name_1  SAMARQAND    Male   53          PhD       Divorced
# 2      ID_2    Name_2   TOSHKENT   Other   71     Bachelor         Single
# 3      ID_3    Name_3    ANDIJON  Female   54  High School       Divorced
# 4      ID_4    Name_4  SAMARQAND  Female   28  High School         Single
#
#    Monthly_Income  Secondary_Income  Monthly_Expenses  ...    Home_Value  \
# 0     1102.824357         85.605919        356.892034  ...  73725.748520
# 1      571.071555         67.197782        504.033877  ...  37205.032774
# 2      929.402413        171.584647        276.175099  ...  62611.154893
# 3      935.537417        347.213245        374.975417  ...  64215.668100
# 4      652.556359        248.451750        453.925177  ...  56292.134621
#
#    Dependents_Count  Digital_Wallet_User  Proposed_Interest_Rate  Decision  \
# ...
